# %%
print("I am ready for Data Analyst Pathway!")
# Out:
# I am ready for Data Analyst Pathway!

# %% [markdown]
# * Excited to work with spreadsheets and organize data.
# * Haven't had a job for about 6 months.
# * Have over 8 years of experience with technical support.
# * Christina Parker, wife and mother to 3 dogs...lol
