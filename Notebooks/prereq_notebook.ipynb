# %% [markdown]
# * Excited to work with spreadsheets and organizing data.
# * Have over 8 years of technical support experience.
# * Christina Parker, wife and mother of 3 dogs...lol.

# %%
vehicles = ['motorcycle', 'RV', 'car', 'truck', 'bus']
